# %%
pip install beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install lxml
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup

# %%
with open('CogntiveScale.html','r') as html_file:
    content= html_file.read()

# %%
soup= BeautifulSoup(content,'lxml')

# %%
#soup.prettify()

# %%
tags=soup.find_all('title')
print(tags)
for tag in tags:
    print(tag.text)
    
SD=soup.find_all('p',class_ = 'center large')
SD
# Out:
# [<title>python Jobs - TimesJobs</title>]
# python Jobs - TimesJobs
# []

# %%
import requests

# %%
html_text=requests.get('https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords=python&txtLocation=').text
soup = BeautifulSoup(html_text,'lxml')

# %%
jobs=soup.find_all('li',class_ ='clearfix job-bx wht-shd-bx')
for job in jobs:
    company_name=job.find('h3', class_ = 'joblist-comp-name').text
    skills=job.find('span', class_='srp-skills').text.replace(' ', '')
    published_date=job.find('span',class_='sim-posted').text
    
    print(f''' 
    Company Name:{company_name}
    Required Skills:{skills}
    published date:{published_date}
    ''')# f method 
    print("")
# Out:
#
#     Company Name:
#     Pure Tech Codex Private Limited
#
#
#     Required Skills:
#
# rest,python,database,django,debugging,mongodb
#
#
#     published date:
# Posted few days ago
#
#
#
#
#     Company Name:
#     Surya Informatics Solutions Pvt. Ltd.
#
#
#     Required Skills:
# python,webtechnologies,linux,mobile,mysql,angularjs,javascript
#
#
#     published date:
# Posted few days ago
#
#
#
#
#     Company Name:
#     GEMINI SOFTWARE SOLUTIONS
#
#
#     Required Skills:
# python,svn,nosql,pythonscripting,git,sqldatabase
#
#
#     published date:
# Posted 2 days ago
#
#
#
#
#     Company Name:
#     Gemini Solutions
#
#
#     Required Skills:
# python,mobile,svn,nosql,pythonscripting,git,api,sqldatabase
#
#
#     published date:
# Posted few days ago
#
#
#
#
#     Company Name:
#     RESEARCH DEVELOPERS
#      (More Jobs)
#
#     Required Skills:
# ...

# %%
## filter out jobs only published a few days ago 
for job in jobs:
    published_date=job.find('span',class_='sim-posted').text
    if 'few' in published_date:
        company_name=job.find('h3', class_ = 'joblist-comp-name').text
        skills=job.find('span', class_='srp-skills').text.replace(' ', '')

    
        print(f''' 
        Company Name:{company_name}
        Required Skills:{skills}
        published date:{published_date}
        ''')# f method 

        print("")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [11], in <cell line: 2>()
#       1 ## filter out jobs only published a few days ago
# ----> 2 for job in jobs:
#       3     published_date=job.find('span',class_='sim-posted').text
#       4     if 'few' in published_date:
#
# NameError: name 'jobs' is not defined

# %%
# Out:
#
# Company Name:
#     Anantha Cyber Tech Pvt Limited
#
#
# Required Skills:
# python,c,c,informationtechnology
#
#
# published date:
# Posted 6 days ago

# %%
print('Put some skill that you are not familiar with')
unfamiliar_skill= input('>')
print(f'Filtering out{unfamiliar_skill}')

for job in jobs:
    published_date=job.find('span',class_='sim-posted').text
    if 'few' in published_date:
        company_name=job.find('h3', class_ = 'joblist-comp-name').text
        skills=job.find('span', class_='srp-skills').text.replace(' ', '')
        
        
        more_info=job.header.h2.a['href']## add href link 
        if unfamiliar_skill not in skills:
            print(f"Company Name:{company_name.strip()}")
            print(f"Skills:{skills.strip()}")
            print(f"More info:{more_info}")
            
            print("")
# Out:
# Put some skill that you are not familiar with
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [5], in <cell line: 2>()
#       1 print('Put some skill that you are not familiar with')
# ----> 2 unfamiliar_skill= input('>')
#       3 print(f'Filtering out{unfamiliar_skill}')
#       5 for job in jobs:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py:1075, in Kernel.raw_input(self, prompt)
#    1071 if not self._allow_stdin:
#    1072     raise StdinNotImplementedError(
#    1073         "raw_input was called, but this frontend does not support input requests."
#    1074     )
# -> 1075 return self._input_request(
#    1076     str(prompt),
#    1077     self._parent_ident["shell"],
#    1078     self.get_parent("shell"),
#    1079     password=False,
#    1080 )
#
# ...

# %%
import time 
def find_jobs()
    html_text=requests.get('https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords=python&txtLocation=').text
    soup = BeautifulSoup(html_text,'lxml')
    jobs=soup.find_all('li',class_ ='clearfix job-bx wht-shd-bx')
    for job in jobs:
        published_date=job.find('span',class_='sim-posted').text
        if 'few' in published_date:
            company_name=job.find('h3', class_ = 'joblist-comp-name').text
            skills=job.find('span', class_='srp-skills').text.replace(' ', '')


            more_info=job.header.h2.a['href']## add href link 
            if unfamiliar_skill not in skills:
                print(f"Company Name:{company_name.strip()}")
                print(f"Skills:{skills.strip()}")
                print(f"More info:{more_info}")

                print("")
if __name__=='__main__':
    while True:_
    find_jobs()
    time_wait=20
    print(f'Waiting:{time_wait}mins...')
    time.sleep(time_wait*60)##allow program pause 600s

# %%
### weitre a info into a new file 
jobs=soup.find_all('li',class_ ='clearfix job-bx wht-shd-bx')


for i,job in enumerate (jobs):
    published_date=job.find('span',class_='sim-posted').text
    if 'few' in published_date:
        company_name=job.find('h3', class_ = 'joblist-comp-name').text
        skills=job.find('span', class_='srp-skills').text.replace(' ', '')
        more_info=job.header.h2.a['href']## add href link 
        
        with open (f'Example2.txt','a+') as writefile:
            writefile.write(f"Company Name:{company_name.strip()}\n")
            writefile.write(f"Skills:{skills.strip()}\n")
            writefile.write(f"More info:{more_info}\n")

##how to write into one file 
                    
            
###?? enumerate

# %% [markdown]
# ## Try another web

# %%
html_tesla=requests.get('https://www.netguru.com/services/machine-learning?utm_term=ai%20companies&utm_campaign=%5BGSN%5D%20%5BBoFu%5D%20%5BNew%20traffic%5D%20%5BT%3ASearch%5D%20%5BHINT%20-%20Campaign%5D%20%5BText%5D%20%5BEstimate%20project%5D%20Company%3B%20agency%3B%20SH%2018-02-2022%09%09%09%09%09%09%09%09%09&utm_source=adwords&utm_medium=ppc&hsa_acc=6111344142&hsa_cam=10710847351&hsa_grp=136927974141&hsa_ad=616112047352&hsa_src=g&hsa_tgt=kwd-308562470819&hsa_kw=ai%20companies&hsa_mt=e&hsa_net=adwords&hsa_ver=3&gclid=CjwKCAjw0dKXBhBPEiwA2bmObcMKgLzP5_cDcPBv1Twbk3sM4mET82JyfDb0VwAavGku9mWtRpKsLBoCbrUQAvD_BwE').text
soup = BeautifulSoup(html_tesla,'lxml')

# %%
title= soup.find_all('title')
title 

all_URL= soup.find_all('a',href=True)

for a in soup.find_all('a', href=True):
    if 'linkedin' in all_URL:
        print( "Found the URL:", a['href'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [64], in <cell line: 1>()
# ----> 1 title= soup.find_all('title').text
#       2 title
#       4 all_URL= soup.find_all('a',href=True)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/bs4/element.py:2289, in ResultSet.__getattr__(self, key)
#    2287 def __getattr__(self, key):
#    2288     """Raise a helpful exception to explain a common code fix."""
# -> 2289     raise AttributeError(
#    2290         "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2291     )
#
# AttributeError: ResultSet object has no attribute 'text'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?
