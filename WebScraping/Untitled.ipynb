# %%
# !pip install selenium

# %%
import os 
from selenium import webdriver

# %%
os.environ['PATH']+=r"/Users/zhenqiangzeng/Downloads"
driver=webdriver.Chrome()

# %%
driver.get('https://www.linkedin.com/groups/12505570/members/')
# driver.implicitly_wait(3)
## save the screenshot 
#driver.save_screenshot('login_page.png')

# %%
from selenium.webdriver.common.by import By
sign_in=driver.find_element(By.LINK_TEXT,'Sign in')
sign_in.click()

# %%
username=driver.find_element(By.ID,"username")
password=driver.find_element(By.ID,"password")
sign_in2=driver.find_element(By.CSS_SELECTOR,"button[data-litms-control-urn='login-submit'][aria-label='Sign in']")

# %%
username.send_keys('gzzeng1010@gmail.com')
password.send_keys('Zzq19981126')
sign_in2.click()

# %%
searching=driver.find_element(By.CSS_SELECTOR,"input[placeholder='Search members'][aria-label='Search members']")

# %%
searching_list=['abc','abd','acd','abe','abf','abz','bce','bde','bcf','beg','zqn','hzw''yfd',
"hso",
"kxb",
"oiv",
"fxc",
"htj",
"lin",
"aur",
"hok",
"gwx",
"mgb",
"xlu",
"brg",
"olh",
"fsz",
"cli",
"nbq",
"tjc",
"awr",
"oqe",
"eio",
"fwe",
"tqx",
"imh",
"esl",
"cvm",
"kqo",
"pen",
"ujp",
"ubd",
"kwo",
"bkg",
"usq",
"vgh",
"jmc",
"nqt",
"uvq",
"mng",
"xhp",
"rsb",
"cin",
"xyw",
"tqk",
"egw",
"szq",
"tfa",
"rqh",
"elm",
"tbh",
"qni",
"drc",
"alt",
"jui",
"btr",
"bum",
"uex",
"nmf",
"vyj",
"hvu",
"bse",
"lmx",
"vxz",
"rjs",
"hys",
"htn",
"rto",
"fad",
"sck",
"wed",
"bqf",
"hfv",
"wlv",
"dce",
"yke",
"dha",
"rwi",
"frd",
"lir",
"jiz",
"akn",
"ofw",
"mjo",
"lqh",
"weo",
"wet",
"ijw",
"agi",
"qty",
"wfp",
"rvf",
"wzx",
"yew",
"iyt",
"rum",
"mwq",
"nct",
"xaj",
"iun",
"trc",
"tzr",
"mne",
"bcr",
"ton",
"lzx",
"hwf",
"agy",
"ivf",
"eul",
"ykd",
"rnp",
"baw",
"qnf",
"pyl",
"ita",
"ajh",
"hbw",
"hbt",
"exf",
"xna",
"uwe",
"ktf",
"cil",
"rhd",
"rej",
"ume",
"sep",
"sby",
"nyq",
"jkt",
"qrg",
"dgt",
"lcp",
"yhq",
"smf",
"tka",
"zeu",
"pln",
"xrs",
"cxn",
"ecp",
"nxk",
"ytw",
"xzi",
"rsj",
"alw",
"neu",
"vpo",
"dzl",
"sac",
"yvd",
"zfp",
"iet",
"fgw",
"uad",
"wun",
"jaq",
"rkb",
"ysl",
"sgd",
"vpc",
"yqx",
"avl",
"xod",
"ima",
"auy",
"aux",
"kpd",
"yem",
"bfl",
"flx",
"lhe",
"ygr",
"klp",
"bdv",
"gac",
"jys",
"oyp",
"ulh",
"jlx",
"ert",
"rdq",
"jit",
"bec",
"noz",
"gbq",
"urm",
"jmw",
"tsp",
"rtz",
"cdz",
"dcs",
"ctg",
"pkm",
"dpi",
"fpa",
"bwm",
"wxu",
"cyj",
"qel",
"sge",
"mak",
"mpi",
"tgy",
"yec",
"rde",
"ubh",
"amv",
"fbv",
"uaz",
"gnq",
"hqz",
"kiw",


]

# %%
searching.send_keys('abd')


# driver.save_screenshot('first_search.png')

# %%
from bs4 import BeautifulSoup
import time
name=[]
title=[]
for a in searching_list:
    searching.send_keys(a)
    src = driver.page_source
    soup = BeautifulSoup(src, 'lxml')
    name_o = soup.find_all('div', {'class': 'artdeco-entity-lockup__title ember-view'})
    for i in name_o:
        name.append(i.text)
        title_o=soup.find_all('div',{'class':'artdeco-entity-lockup__subtitle ember-view'})
    for t in title_o:
        title.append(t.text)
    searching.clear()
    time.sleep(5)
print(len(name))
print(len(title))
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Input In [12], in <cell line: 5>()
#      13     for t in title_o:
#      14         title.append(t.text)
# ---> 15     searching.clear()
#      16     time.sleep(5)
#      17 print(len(name))
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/webelement.py:116, in WebElement.clear(self)
#     114 def clear(self) -> None:
#     115     """Clears the text if it's a text entry element."""
# --> 116     self._execute(Command.CLEAR_ELEMENT)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/webelement.py:410, in WebElement._execute(self, command, params)
#     408     params = {}
#     409 params["id"] = self._id
# --> 410 return self._parent.execute(command, params)
#
# ...

# %%
len(name)
# Out:
# 1160

# %%
soup = BeautifulSoup(src, 'lxml')

# %%
name_o = soup.find_all('div', {'class': 'artdeco-entity-lockup__title ember-view'})

# %%
name=[]
for i in name_o:
    name.append(i.text)
print(name)
# Out:
# ['\n          ABDUL REHMAN\n        \n', '\n          mostafa abdo\n        \n', '\n          Esraa Abd Elrahman\n        \n', '\n          Mohamed Abd-Elaziz\n        \n', '\n          Abdul Majid\n        \n', '\n          Aysel Abdullayeva\n        \n', '\n          Abdul Gafoor\n        \n', '\n          Saleem Abdul\n        \n', '\n          ABDUL ARFATH\n        \n', '\n          Reem Abd Elhady\n        \n', '\n          ABDELKARIM ELAISSAOUY\n        \n', '\n          Mohamed Abdeltawab\n        \n', '\n          Abdul Shakoor\n        \n', '\n          Abdulrahman Alaqeeli\n        \n', '\n          Rao Abdul Hai\n        \n', '\n          Abdallah Fathy\n        \n', '\n          Abdul Basit\n        \n', '\n          Abdullah Watheq AlBarazi\n        \n', '\n          muneer abdulsttar\n        \n', '\n          Muhammad Abdur Rehman\n        \n']

# %%
title=[]
title_o=soup.find_all('div',{'class':'artdeco-entity-lockup__subtitle ember-view'})
title_o
for t in title_o:
    title.append(t.text)
print(title)
# Out:
# ['\n          Founder & CEO at LOCAL TRADERS | Blockchain and Cryptocurrency| P2P | Cyber Security Analyst | #LCT\n        ', '\n          software developer\n        ', '\n          Fresh graduate \n        ', '\n          Founder at Gebhaly.com\n        ', '\n          Founder & CEO | Digital Business Development | Website Developer & Markter | IT Trainer\n        ', '\n          Frontend Developer\n        ', '\n          Talent Acquisition Specialist\n        ', '\n          Talent Acquisition consultant\n        ', '\n          Team leader -Talent acquisition and operations\n        ', '\n          Technical Recruiter Specialist at Hired Recruitment, I connect top talents with top-notch employers in the market.\n        ', "\n          ✦ 𝙁𝙪𝙡𝙡 𝙎𝙩𝙖𝙘𝙠 𝕯𝐞𝐯𝐞𝐥𝐨𝐩𝐞𝐫 |  𝐆𝐫𝐚𝐩𝐡𝐢𝐜 𝕯𝖊𝖘𝖎𝖌𝖓𝖊𝖗 | 𝙁𝙧𝙚𝙚𝙡𝙖𝙣𝙘𝙚𝙧 ✦  |    🔍                    à la Recherche Actif D'un Stage PFE Pour Une Durée de 4 à 6 Mois\n        ", '\n          Front end web developer\n        ', '\n          Student at NED Universi
# ...

# %%
searching.clear()

# %%
import requests
get_ipython().system(' pip install bs4')
from bs4 import BeautifulSoup
get_ipython().system(' pip install lxml')
import pandas as pd
import numpy as np

# %%
html = driver.page_source
#html

# %%
page_source=[]
for i in range(len(searching_list)):
    searching.send_keys(searching_list[i])
    html=driver.page_source.text
    page_source.append(html)
    print(len(page_source))
    searching.clear()
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Input In [97], in <cell line: 2>()
#       1 page_source=[]
#       2 for i in range(len(searching_list)):
# ----> 3     searching.send_keys(searching_list[i])
#       4     html=driver.page_source.text
#       5     page_source.append(html)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/webelement.py:233, in WebElement.send_keys(self, *value)
#     230             remote_files.append(self._upload(file))
#     231         value = "\n".join(remote_files)
# --> 233 self._execute(
#     234     Command.SEND_KEYS_TO_ELEMENT, {"text": "".join(keys_to_typing(value)), "value": keys_to_typing(value)}
#     235 )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/webelement.py:410, in WebElement._execute(self, command, params)
#     408     params = {}
# ...

# %%
soup=BeautifulSoup(,'lxml')

# %%
# page_source[0]

# %%
member_names=[]
for j in range(len(page_source)):
    soup=BeautifulSoup(page_source[j],'lxml')
    secrtion=soup.find_all('div',class_='artdeco-entity-lockup artdeco-entity-lockup--size-4 ember-view pr4')
    # print(secrtion)
    # for k in range(len(html_names)):
    #     print(html_names[k].text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [96], in <cell line: 2>()
#       3 soup=BeautifulSoup(page_source[j],'lxml').text
#       4 #print(soup)
# ----> 5 secrtion=soup.find_all('div',class_='artdeco-entity-lockup artdeco-entity-lockup--size-4 ember-view pr4')
#
# AttributeError: 'str' object has no attribute 'find_all'

# %%
member_names=soup.find_all('div',class_='artdeco-entity-lockup__title ember-view')
member_names
# Out:
# []

# %%
print(main2)

# %%
# driver.close
# Out:
# <bound method WebDriver.close of <selenium.webdriver.chrome.webdriver.WebDriver (session="b7a19d74b61aef6ed05194cfadad81ef")>>

# %%
x=121
x=str(x)
print(x)
# Out:
# 121

# %%
x[::-1]
# Out:
# '121'

# %%
x[::1]
# Out:
# '121'

# %%
x[::1]==x[::-1]
# Out:
# True

# %%
def isPalindrome(x):
        """
        :type x: int
        :rtype: bool
        """
        x=str(x)
        return (x[::1]== x[::-1])

# %%
isPalindrome(121)
# Out:
# True
